# %% [markdown]
# ##

# %%
from langchain_discord_shikenso.tools.discord_send_messages import DiscordSendMessage
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import langchain_discord_shikenso
#
# File c:\Users\user\potenup\Wante\.venv\Lib\site-packages\langchain_discord_shikenso\__init__.py:3
#       1 from importlib import metadata
# ----> 3 from langchain_discord.toolkits import DiscordToolkit
#       5 try:
#       6     __version__ = metadata.version(__package__)
#
# File c:\Users\user\potenup\Wante\.venv\Lib\site-packages\langchain_discord\__init__.py:1
# ----> 1 from .webhook import *
#
# File c:\Users\user\potenup\Wante\.venv\Lib\site-packages\langchain_discord\webhook.py:26
#       8 from langchain.output_parsers import StructuredOutputParser, ResponseSchema
#      10 ## INFO: The following code is not used anymore, but I keep it here for reference. It is good to keep for the future when more errors are handled by the package.
#      11
# ...
